# %%
# Let's import our dependencies. 
import pandas as pd
import requests
import json
import numpy as np

# Import the API key
from config_br import geoapify_key

# %%
print(geoapify_key)
# Out:
# 8197c8d7f0e44683b0fa23eb2e7c1a63

# %%
# Read our CSV file into pandas dataframe. 

miami_df = pd.read_csv('miami-housing_2016.csv')
miami_df.head()
# Out:
#     LATITUDE  LONGITUDE      PARCELNO  SALE_PRC  LND_SQFOOT  TOT_LVG_AREA  \
# 0  25.891031 -80.160561  622280070620  440000.0        9375          1753
# 1  25.891324 -80.153968  622280100460  349000.0        9375          1715
# 2  25.891334 -80.153740  622280100470  800000.0        9375          2276
# 3  25.891765 -80.152657  622280100530  988000.0       12450          2058
# 4  25.891825 -80.154639  622280100200  755000.0       12800          1684
#
#    SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  WATER_DIST  CNTR_DIST  SUBCNTR_DI  \
# 0              0     2815.9     12811.4       347.6    42815.3     37742.2
# 1              0     4359.1     10648.4       337.8    43504.9     37340.5
# 2          49206     4412.9     10574.1       297.1    43530.4     37328.7
# 3          10033     4585.0     10156.5         0.0    43797.5     37423.2
# 4          16681     4063.4     10836.8       326.6    43599.7     37550.8
#
#    HWY_DIST  age  avno60plus  month_sold  structure_quality
# 0   15954.9   67           0           8                  4
# 1   18125.0   63           0           9                  4
# 2   18200.5   61           0           2                  4
# 3   18514.4   63           0           9                  4
# 4   17903.4   42           0           7                  4

# %%
miami_df['LATITUDE_scale']= np.round(miami_df['LATITUDE'],3)
miami_df['LONGITUDE_scale']= np.round(miami_df['LONGITUDE'],3)

# %%
miami_df['LATITUDE_scale'] = miami_df['LATITUDE_scale'].map('{:.3f}'.format)
miami_df['LONGITUDE_scale'] = miami_df['LONGITUDE_scale'].map('{:.3f}'.format)

# %%
# Check the dataframe to ensure that there are no missing values. 
miami_df.head(10)
#miami_df.info()
#miami_df['LATITUDE_scale'].unique()
#miami_df['LONGITUDE_scale'].nunique()
# Out:
#     LATITUDE  LONGITUDE      PARCELNO   SALE_PRC  LND_SQFOOT  TOT_LVG_AREA  \
# 0  25.891031 -80.160561  622280070620   440000.0        9375          1753
# 1  25.891324 -80.153968  622280100460   349000.0        9375          1715
# 2  25.891334 -80.153740  622280100470   800000.0        9375          2276
# 3  25.891765 -80.152657  622280100530   988000.0       12450          2058
# 4  25.891825 -80.154639  622280100200   755000.0       12800          1684
# 5  25.892060 -80.161354  622280070180   630000.0        9900          1531
# 6  25.892473 -80.157217  622280080100  1020000.0       10387          1753
# 7  25.893019 -80.157426  622280080400   850000.0       10272          1663
# 8  25.893046 -80.161556  622280080020   250000.0        9375          1493
# 9  25.893050 -80.158048  622280080370  1220000.0       13803          3077
#
#    SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  WATER_DIST  CNTR_DIST  SUBCNTR_DI  \
# 0              0     2815.9     12811.4       347.6    42815.3     37742.2
# 1              0     4359.1     10648.4       337.8    43504.9     37340.5
# 2          49206     4412.9     10574.1       297.1    43530.4     37328.7
# 3          10033     4585.0     10156.5         0.0    43797.5     37423.2
# 4          16681     4063.4     10836.8       326.6    43599.7     37550.8
# 5           2978     2391.4     13017.0       188.9    43135.1     38176.2
# 6          23116     3277.4     11667.8         0.0    43598.7     37973.9
# 7          34933     3112.4     11718.1        10.5    43780.8     38198.3
# 8          11668     2081.8     13043.8        51.5    43481.7     38542.0
# 9          34580     2937.7     11917.7         9.7    43730.1     38235.2
#
#    HWY_DIST  age  avno60plus  month_sold  structure_quality LATITUDE_scale  \
# 0   15954.9   67           0           8                  4         25.891
# 1   18125.0   63           0           9                  4         25.891
# 2   18200.5   61           0           2                  4         25.891
# 3   18514.4   63           0           9                  4         25.892
# 4   17903.4   42           0           7                  4         25.892
# 5   15687.2   41           0           2                  4         25.892
# 6   17068.2   63           0           2                  5         25.892
# 7   16989.9   21           0           9                  4         25.893
# 8   15623.3   56           0           3                  4         25.893
# 9   16787.0   63           0          11                  5         25.893
#
#   LONGITUDE_scale
# 0         -80.161
# 1         -80.154
# 2         -80.154
# 3         -80.153
# 4         -80.155
# 5         -80.161
# 6         -80.157
# 7         -80.157
# 8         -80.162
# 9         -80.158

# %%
miami_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13932 entries, 0 to 13931
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LATITUDE           13932 non-null  float64
#  1   LONGITUDE          13932 non-null  float64
#  2   PARCELNO           13932 non-null  int64
#  3   SALE_PRC           13932 non-null  float64
#  4   LND_SQFOOT         13932 non-null  int64
#  5   TOT_LVG_AREA       13932 non-null  int64
#  6   SPEC_FEAT_VAL      13932 non-null  int64
#  7   RAIL_DIST          13932 non-null  float64
#  8   OCEAN_DIST         13932 non-null  float64
#  9   WATER_DIST         13932 non-null  float64
#  10  CNTR_DIST          13932 non-null  float64
#  11  SUBCNTR_DI         13932 non-null  float64
#  12  HWY_DIST           13932 non-null  float64
#  13  age                13932 non-null  int64
#  14  avno60plus         13932 non-null  int64
#  15  month_sold         13932 non-null  int64
#  16  structure_quality  13932 non-null  int64
#  17  LATITUDE_scale     13932 non-null  object
#  18  LONGITUDE_scale    13932 non-null  object
# dtypes: float64(9), int64(8), object(2)
# memory usage: 2.0+ MB

# %%
sample_miami_df = miami_df.sample(n=150,random_state=1)
sample_miami_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 12782 to 3111
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LATITUDE           150 non-null    float64
#  1   LONGITUDE          150 non-null    float64
#  2   PARCELNO           150 non-null    int64
#  3   SALE_PRC           150 non-null    float64
#  4   LND_SQFOOT         150 non-null    int64
#  5   TOT_LVG_AREA       150 non-null    int64
#  6   SPEC_FEAT_VAL      150 non-null    int64
#  7   RAIL_DIST          150 non-null    float64
#  8   OCEAN_DIST         150 non-null    float64
#  9   WATER_DIST         150 non-null    float64
#  10  CNTR_DIST          150 non-null    float64
#  11  SUBCNTR_DI         150 non-null    float64
#  12  HWY_DIST           150 non-null    float64
#  13  age                150 non-null    int64
#  14  avno60plus         150 non-null    int64
#  15  month_sold         150 non-null    int64
#  16  structure_quality  150 non-null    int64
#  17  LATITUDE_scale     150 non-null    object
#  18  LONGITUDE_scale    150 non-null    object
# dtypes: float64(9), int64(8), object(2)
# memory usage: 23.4+ KB

# %%
# keeping the sample ^^ at n=150 so I don't max out my API calls today. We should up the sample to n=1000 when we run for real.

# %%
# Find the number of schools in a 1,000m radius of each house. 
# Also, find the zip code for the first school in each record. We will use this zip code as a proxy for the zip code of the home.

check_lat_lon =[]
lat_list = []
long_list =[]
school_count =[]
zip_list =[]

for index,row in sample_miami_df.iterrows():
    lat_lon = row["LATITUDE_scale"]+row["LONGITUDE_scale"]
    if lat_lon not in check_lat_lon:
        check_lat_lon.append(lat_lon)
        categories = "education.school"
        radius = 1000
        filters = f'circle:{row["LONGITUDE_scale"]},{row["LATITUDE_scale"]},{radius}'
        bias = f'proximity:{row["LONGITUDE_scale"]},{row["LATITUDE_scale"]}'
        limit = 100

        # set up a parameters dictionary
        params = {
            "categories":categories,
            "bias":bias,
            "apiKey":geoapify_key,    
            "limit":limit,
            "filter":filters,
            "bias":bias,
        }
        base_url = "https://api.geoapify.com/v2/places"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params)   
        # print the response url, avoid doing for public github repos in order to avoid exposing key
        print(response.url)   
        lat_list.append(row["LATITUDE_scale"])
        long_list.append(row["LONGITUDE_scale"])
        places_data = response.json()
        school_count.append(len(places_data["features"]))
        try:
            zip_list.append(places_data["features"][0]["properties"]["postcode"])
        except:
            print("No schools in this area")
            zip_list.append(0)
# Out:
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.455%2C25.665&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.455%2C25.665%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.175%2C25.851&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.175%2C25.851%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.387%2C25.540&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.387%2C25.540%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.381%2C25.821&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.381%2C25.821%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.171%2C25.916&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.171%2C25.916%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.391%2C25.595&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.391%2C25.595%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.259%2C25.719&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.259%2C25.719%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.405%2C25.593&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.405%2C25.593%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.423%2C25.631&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.423%2C25.631%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.335%2C25.567&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.335%2C25.567%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.338%2C25.596&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.338%2C25.596%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.417%2C25.621&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.417%2C25.621%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.405%2C25.635&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.405%2C25.635%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.446%2C25.632&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.446%2C25.632%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.443%2C25.637&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.443%2C25.637%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.196%2C25.823&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.196%2C25.823%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.173%2C25.860&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.173%2C25.860%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.239%2C25.912&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.239%2C25.912%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.338%2C25.872&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.338%2C25.872%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.217%2C25.877&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.217%2C25.877%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.357%2C25.563&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.357%2C25.563%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.428%2C25.715&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.428%2C25.715%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.324%2C25.627&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.324%2C25.627%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.423%2C25.512&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.423%2C25.512%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.444%2C25.474&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.444%2C25.474%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.382%2C25.672&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.382%2C25.672%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.242%2C25.914&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.242%2C25.914%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.304%2C25.814&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.304%2C25.814%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.183%2C25.838&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.183%2C25.838%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.450%2C25.633&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.450%2C25.633%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.422%2C25.468&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.422%2C25.468%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80
2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.381%2C25.558&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.381%2C25.558%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.384%2C25.659&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.384%2C25.659%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.347%2C25.581&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.347%2C25.581%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.216%2C25.893&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.216%2C25.893%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.150%2C25.959&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.150%2C25.959%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.373%2C25.715&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.373%2C25.715%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.220%2C25.827&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.220%2C25.827%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.457%2C25.688&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.457%2C25.688%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.218%2C25.824&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.218%2C25.824%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.220%2C25.840&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.220%2C25.840%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.222%2C25.758&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.222%2C25.758%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.375%2C25.541&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.375%2C25.541%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.327%2C25.636&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.327%2C25.636%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.335%2C25.770&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.335%2C25.770%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.280%2C25.865&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.280%2C25.865%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.458%2C25.459&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.458%2C25.459%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.383%2C25.535&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.383%2C25.535%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.433%2C25.473&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.433%2C25.473%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.397%2C25.742&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.397%2C25.742%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.282%2C25.746&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.282%2C25.746%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.272%2C25.928&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.272%2C25.928%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.401%2C25.507&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.401%2C25.507%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.418%2C25.485&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.418%2C25.485%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.175%2C25.924&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.175%2C25.924%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.399%2C25.670&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.399%2C25.670%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.373%2C25.615&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.373%2C25.615%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.440%2C25.606&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.440%2C25.606%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.340%2C25.624&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.340%2C25.624%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.360%2C25.720&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.360%2C25.720%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.203%2C25.966&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.203%2C25.966%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.205%2C25.820&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.205%2C25.820%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.440%2C25.511&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.440%2C25.511%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.412%2C25.727&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.412%2C25.727%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.179%2C25.880&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.179%2C25.880%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.339%2C25.715&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.339%2C25.715%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.402%2C25.533&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.402%2C25.533%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.421%2C25.497&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.421%2C25.497%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.438%2C25.603&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.438%2C25.603%2C1000
# No schools in this area
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.177%2C25.882&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.177%2C25.882%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.427%2C25.598&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.427%2C25.598%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.425%2C25.604&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.425%2C25.604%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.310%2C25.671&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.310%2C25.671%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.370%2C25.652&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.370%2C25.652%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.369%2C25.633&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.369%2C25.633%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.269%2C25.871&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.269%2C25.871%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.454%2C25.676&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.454%2C25.676%2C1000
# https://api.geoapify.com/v2/places?categories=education.school&bias=proximity%3A-80.290%2C25.766&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.290%2C25.766%2C1000

# %%
schools_count_df = pd.DataFrame( {
    "LATITUDE_scale": lat_list,
    "LONGITUDE_scale": long_list,
    "count" : school_count,
    "postcodes" : zip_list
    })

schools_count_df
# Out:
#     LATITUDE_scale LONGITUDE_scale  count postcodes
# 0           25.665         -80.455      2     33196
# 1           25.851         -80.175      6     33138
# 2           25.540         -80.387      0         0
# 3           25.821         -80.381      2     33178
# 4           25.916         -80.171      7     33162
# ..             ...             ...    ...       ...
# 145         25.652         -80.370      4     33176
# 146         25.633         -80.369      3     33176
# 147         25.871         -80.269      6     33013
# 148         25.676         -80.454      3     33196
# 149         25.766         -80.290      7     33144
#
# [150 rows x 4 columns]

# %%
# NOTE: Eventually, we need to figure out how to get the zip codes for records that didn't have a school in the radius.

# %%
# Now we're looking for the number of hospitals within 1,000m of each house. 

check_lat_lon =[]
lat_list = []
long_list =[]
hosp_count =[]
hosp_zip_list =[]

for index,row in sample_miami_df.iterrows():
    lat_lon = row["LATITUDE_scale"]+row["LONGITUDE_scale"]
    if lat_lon not in check_lat_lon:
        check_lat_lon.append(lat_lon)
        categories = "healthcare.hospital"
        radius = 1000
        filters = f'circle:{row["LONGITUDE_scale"]},{row["LATITUDE_scale"]},{radius}'
        bias = f'proximity:{row["LONGITUDE_scale"]},{row["LATITUDE_scale"]}'
        limit = 100

        # set up a parameters dictionary
        params = {
            "categories":categories,
            "bias":bias,
            "apiKey":geoapify_key,    
            "limit":limit,
            "filter":filters,
            "bias":bias,
        }
        base_url = "https://api.geoapify.com/v2/places"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params)   
        # print the response url, avoid doing for public github repos in order to avoid exposing key
        print(response.url)   
        lat_list.append(row["LATITUDE_scale"])
        long_list.append(row["LONGITUDE_scale"])
        places_data = response.json()
        hosp_count.append(len(places_data["features"]))
        try:
            hosp_zip_list.append(places_data["features"][0]["properties"]["postcode"])
        except:
            print("No hospitals in this area")
            hosp_zip_list.append(0)
# Out:
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.455%2C25.665&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.455%2C25.665%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.175%2C25.851&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.175%2C25.851%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.387%2C25.540&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.387%2C25.540%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.381%2C25.821&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.381%2C25.821%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.171%2C25.916&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.171%2C25.916%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.391%2C25.595&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.391%2C25.595%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.259%2C25.719&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.259%2C25.719%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.405%2C25.593&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.405%2C25.593%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.423%2C25.631&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.423%2C25.631%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.335%2C25.567&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.335%2C25.567%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.338%2C25.596&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.338%2C25.596%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.417%2C25.621&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.417%2C25.621%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.405%2C25.635&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.405%2C25.635%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.446%2C25.632&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.446%2C25.632%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.443%2C25.637&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.443%2C25.637%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.196%2C25.823&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.196%2C25.823%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.173%2C25.860&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.173%2C25.860%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.239%2C25.912&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.239%2C25.912%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.338%2C25.872&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.338%2C25.872%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.217%2C25.877&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.217%2C25.877%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.357%2C25.563&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.357%2C25.563%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.428%2C25.715&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.428%2C25.715%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.324%2C25.627&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.324%2C25.627%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.423%2C25.512&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.423%2C25.512%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.444%2C25.474&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.444%2C25.474%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.382%2C25.672&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.382%2C25.672%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.242%2C25.914&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.242%2C25.914%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.304%2C25.814&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.304%2C25.814%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.183%2C25.838&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.183%2C25.838%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.450%2C25.633&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.450%2C25.633%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.422%2C25.468&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.422%2C25.468%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.199%2C25.900&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.199%2C25.900%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.446%2C25.636&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.446%2C25.636%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.430%2C25.473&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.430%2C25.473%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.421%2C25.739&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.421%2C25.739%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.391%2C25.698&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.391%2C25.698%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.436%2C25.707&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.436%2C25.707%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.295%2C25.637&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.295%2C25.637%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.390%2C25.580&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.390%2C25.580%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.387%2C25.573&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.387%2C25.573%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.206%2C25.759&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.206%2C25.759%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.405%2C25.508&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.405%2C25.508%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.444%2C25.606&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.444%2C25.606%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.259%2C25.722&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.259%2C25.722%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.204%2C25.875&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.204%2C25.875%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.275%2C25.839&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.275%2C25.839%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.402%2C25.559&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80
apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.458%2C25.459%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.383%2C25.535&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.383%2C25.535%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.433%2C25.473&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.433%2C25.473%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.397%2C25.742&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.397%2C25.742%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.282%2C25.746&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.282%2C25.746%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.272%2C25.928&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.272%2C25.928%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.401%2C25.507&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.401%2C25.507%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.418%2C25.485&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.418%2C25.485%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.175%2C25.924&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.175%2C25.924%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.399%2C25.670&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.399%2C25.670%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.373%2C25.615&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.373%2C25.615%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.440%2C25.606&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.440%2C25.606%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.340%2C25.624&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.340%2C25.624%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.360%2C25.720&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.360%2C25.720%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.203%2C25.966&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.203%2C25.966%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.205%2C25.820&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.205%2C25.820%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.440%2C25.511&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.440%2C25.511%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.412%2C25.727&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.412%2C25.727%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.179%2C25.880&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.179%2C25.880%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.339%2C25.715&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.339%2C25.715%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.402%2C25.533&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.402%2C25.533%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.421%2C25.497&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.421%2C25.497%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.438%2C25.603&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.438%2C25.603%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.177%2C25.882&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.177%2C25.882%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.427%2C25.598&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.427%2C25.598%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.425%2C25.604&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.425%2C25.604%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.310%2C25.671&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.310%2C25.671%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.370%2C25.652&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.370%2C25.652%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.369%2C25.633&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.369%2C25.633%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.269%2C25.871&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.269%2C25.871%2C1000
# No hospitals in this area
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.454%2C25.676&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.454%2C25.676%2C1000
# https://api.geoapify.com/v2/places?categories=healthcare.hospital&bias=proximity%3A-80.290%2C25.766&apiKey=8197c8d7f0e44683b0fa23eb2e7c1a63&limit=100&filter=circle%3A-80.290%2C25.766%2C1000
# No hospitals in this area

# %%
hosp_count_df = pd.DataFrame( {
    "LATITUDE_scale": lat_list,
    "LONGITUDE_scale": long_list,
    "hosp count" : hosp_count,
    "postcodes" : hosp_zip_list
    })

hosp_count_df
# Out:
#     LATITUDE_scale LONGITUDE_scale  hosp count postcodes
# 0           25.665         -80.455           0         0
# 1           25.851         -80.175           0         0
# 2           25.540         -80.387           0         0
# 3           25.821         -80.381           0         0
# 4           25.916         -80.171           0         0
# ..             ...             ...         ...       ...
# 145         25.652         -80.370           0         0
# 146         25.633         -80.369           0         0
# 147         25.871         -80.269           0         0
# 148         25.676         -80.454           1     33156
# 149         25.766         -80.290           0         0
#
# [150 rows x 4 columns]

# %%
schools_count_df.head(30)
print(schools_count_df['postcodes'].value_counts())

# %%
schools_count_df.head()

# %%
# Determine if there are any duplicate parcel numbers. 

miami_df["PARCELNO"].nunique()

# We see there are duplicate parcel numbers, but it seems that this is because the same property was sold twice (or more) in the same year.

# %%
miami_df.columns

# %%
school_merged_df = pd.merge(miami_df, schools_count_df, on = ['LATITUDE_scale','LONGITUDE_scale'])
school_merged_df
school_merged_df.sort_values(by=["count"],ascending=False)

# %%
# convert response to json
#places_data = response.json()

# Print the json (pretty printed)
#print(json.dumps(places_data, indent=4, sort_keys=True))

# %%
# convert response to json
#places_data = response.json()

# Print the json (pretty printed)
#print(json.dumps(places_data, indent=4, sort_keys=True))
